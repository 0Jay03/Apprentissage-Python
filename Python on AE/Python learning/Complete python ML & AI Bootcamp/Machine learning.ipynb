# %% [markdown]
# """" ANALYSE EXPLORATOIRE DES DONNEES """"

# %%
# Mean
data = [1,2,3,4,5,6,7,3,2,5,6,2,5,3,2,5,6,32,5,46,3,24,5,6,24,24,24]

import numpy as np

mean = np.mean(data)
mean 

median = np.median(data)

from scipy import stats 
mode = stats.mode(data)
print(mode)
# Out:
# ModeResult(mode=np.int64(5), count=np.int64(6))

# %%
# Standard Deviation -> Number that describes how spread out the values are
sd = np.std(data)
print(sd)

# Variance 
var = np.var(data)
print(var)
# Out:
# 11.14267122754001
# 124.159122085048

# %%
# Percentile -> give you a number that describes the value that a given percent of the values are lower than
p75 = np.percentile(data, 75)
p75
# Out:
# np.float64(6.5)

# %%
# Random Data
data = np.random.uniform(20,60,200)
p80 = np.percentile(data,80)
p80
# 80 % percentile is 50.07, means that 80% of the people are 50.07 or younger thnt that
# Out:
# np.float64(50.0744160808101)

# %% [markdown]
# """" DATA CLEANING AND HANDLING MISSING DATA""""

# %%
import pandas as pd 
from sklearn.datasets import load_iris
iris =  load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target

#Display the data
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Handling the missing data
# Simulating the missing data

np.random.seed(42)
missing_rows = np.random.choice(iris_df.index, size=10, replace=False)
iris_df.loc[missing_rows, 'sepal length (cm)'] = np.nan

print("dataset with missing values")
iris_df
# Out:
# dataset with missing values
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
# Handling the missing values

iris_df['sepal length (cm)'].fillna(iris_df['sepal length (cm)'].mean(), inplace=True)
iris_df
# Out:
# C:\Users\Brice Daleu\AppData\Local\Temp\ipykernel_1776\2071827515.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   iris_df['sepal length (cm)'].fillna(iris_df['sepal length (cm)'].mean(), inplace=True)
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# ...

# %%
# Handling the missing values

iris_df['sepal length (cm)'].fillna(iris_df['sepal length (cm)'].median(), inplace=True)
iris_df
# Out:
# C:\Users\Brice Daleu\AppData\Local\Temp\ipykernel_1776\2344602099.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   iris_df['sepal length (cm)'].fillna(iris_df['sepal length (cm)'].median(), inplace=True)
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# ...

# %%
# Dropping rows with missing data
iris_df.dropna(inplace=True)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
# FEATURE SCALING
# Technique 01: Normalization
# Technique 02: Standardization

import pandas as pd 
from sklearn.datasets import load_iris
iris =  load_iris()
data = pd.DataFrame(data=iris.data, columns=iris.feature_names)
data['target'] = iris.target
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Select features (Dropping the target column
features = data.iloc[:, :-1]
features.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# # 1. Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
 
normalizer = MinMaxScaler()
normalized_data = normalizer.fit_transform(features)
normalized_df = pd.DataFrame(normalized_data, columns=features.columns)
normalized_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0           0.222222          0.625000           0.067797          0.041667
# 1           0.166667          0.416667           0.067797          0.041667
# 2           0.111111          0.500000           0.050847          0.041667
# 3           0.083333          0.458333           0.084746          0.041667
# 4           0.194444          0.666667           0.067797          0.041667

# %%
# Plot normalized 
plt.figure(figsize=(10,5))
plt.scatter(normalized_df.iloc[:,0], normalized_df.iloc[:,1], c=data['target'], cmap="viridis")
plt.xlabel(features.columns[0])
plt.ylabel(features.columns[1])
plt.show()

# %% [markdown]
# # 2.  Standardization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
standardized_data = scaler.fit_transform(features)
standardized_df = pd.DataFrame(standardized_data, columns=features.columns)
standardized_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# 3          -1.506521          0.098217          -1.283389         -1.315444
# 4          -1.021849          1.249201          -1.340227         -1.315444

# %%
standardized_df.iloc[:,1].mean()

sd = np.std(standardized_df.iloc[:,1])
sd
# Out:
# 0.9999999999999993

# %%
# Plot standardized 
plt.figure(figsize=(10,5))
plt.scatter(standardized_df.iloc[:,0], standardized_df.iloc[:,1], c=data['target'], cmap="viridis")
plt.xlabel(features.columns[0])
plt.ylabel(features.columns[1])
plt.show()

# %% [markdown]
# ## Data Transformation and Encoding

# %%
import pandas as pd 
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
import seaborn as sns

# Load Titanic dataset from seaborn 
sns.set(style="darkgrid")
data = sns.load_dataset("titanic")
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
