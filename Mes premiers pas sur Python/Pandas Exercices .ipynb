# %%
import pandas as pd

# %% [markdown]
#  # Exercice1: format d'un DataFrame
#
# Le directeur d'une épicerie recense les informations suivantes sur son stock de produits alimentaires :
#
# + 100 pots de miel dont la date d'expiration est le 10/08/2025 et valant 2€ l'unité.
#
# + 55 paquets de farine expirant le 25/09/2024 coûtant chacun 3€.
#
# + 1800 bouteilles de vin à 10€ l'unité expirant le 15/10/2023.
#
# + À partir d'un dictionnaire, créer et afficher le DataFrame df qui pour chaque produit doit contenir de manière organisée :
# >+ Son nom.
# >+ Sa date d'expiration.
# >+ Sa quantité.
# >+ Son prix à l'unité.
#
# *Vous choisirez des noms de colonne pertinents et l'index sera celui par défaut (dans ce cas on ne spécifie pas le paramètre index).*

# %%
# V0
# Creation d'un dictionnaire
dictionnaire = {"Pots de miel": ["25/09/2024", 100, 2],
                "Paquets de farine": ["25/09/2024", 55, 3],
                "Bouteille de vin": ["15/10/2023", 1800, 10]}
# Creation de notre DataFrame
df = pd.DataFrame(data = dictionnaire, 
                  index = [ "Date d'expiration", "Quantité", "Prix Unitaire"])
df
# Out:
#                   Pots de miel Paquets de farine Bouteille de vin
# Date d'expiration   25/09/2024        25/09/2024       15/10/2023
# Quantité                   100                55             1800
# Prix Unitaire                2                 3               10

# %%
# V1
# Création d'un dictionnaire
dictionnaire = {'DLU': ['10/08/2025', '25/09/2024', '15/10/2023'],
                'QT': [100, 55, 1800],
                'PU': [2, 3, 10]}

# Instanciation d'un DataFrame
df = pd.DataFrame(data = dictionnaire,
                  index = ['miel', 'farine', 'vin'])
df
# Out:
#                DLU    QT  PU
# miel    10/08/2025   100   2
# farine  25/09/2024    55   3
# vin     15/10/2023  1800  10

# %%
# V2
dictionnaire = {"Produit"          : ['miel', 'farine', 'vin'],
                "Date d'expiration": ['10/08/2025', '25/09/2024', '15/10/2023'],
                "Quantité"         : [100, 55, 1800],
                "Prix à l'unité"   : [2, 3, 10]}

df = pd.DataFrame(dictionnaire)

df
# Out:
#   Produit Date d'expiration  Quantité  Prix à l'unité
# 0    miel        10/08/2025       100               2
# 1  farine        25/09/2024        55               3
# 2     vin        15/10/2023      1800              10

# %% [markdown]
# # Exercice 2: Création d'un DataFrame à partir d'un fichier de données
#
# + Charger les données contenues dans le fichier transactions.csv dans un DataFrame nommé transactions :
#
#
# + Le fichier se trouve dans dossier Github de Quantik mais vous pourriez le charger en local.
# + Les colonnes sont séparées par une virgule.
# + Les noms des colonnes sont renseignés sur la première ligne du fichier.
# + Les lignes de la base sont indexées par la colonne "transaction_id" qui est aussi la première colonne
# >link = 'https://raw.githubusercontent.com/QuantikDataStudio/dataset/main/Transactions.csv'

# %%
import pandas as pd

# %%
transactions = pd.read_csv('https://raw.githubusercontent.com/QuantikDataStudio/dataset/main/Transactions.csv' , sep = ',', header = 0, index_col = 0 ) #index_col=0 ou index_col = "transaction_id"
transactions
# Out:
#                 cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# transaction_id
# 80712190438      270351  28-02-2014                 1              1   -5
# 29258453508      270384  27-02-2014                 5              3   -5
# 51750724947      273420  24-02-2014                 6              5   -2
# 93274880719      271509  24-02-2014                11              6   -3
# 51750724947      273420  23-02-2014                 6              5   -2
# ...                 ...         ...               ...            ...  ...
# 94340757522      274550  25-01-2011                12              5    1
# 89780862956      270022  25-01-2011                 4              1    1
# 85115299378      271020  25-01-2011                 2              6    4
# 72870271171      270911  25-01-2011                11              5    3
# 77960931771      271961  25-01-2011                11              5    1
#
#                 Rate      Tax  total_amt Store_type
# ...

# %% [markdown]
# # Exercice 3: Première exploration d'un dataset grâce à la classe DataFrame
#
# Ce notebook présente les principales méthodes de la classe DataFrame pour une analyse rapide des données :
#
# - **Aperçu des données** : Utilisez `head`, `columns` et `shape` pour visualiser rapidement les données et leur structure.
# - **Sélection de valeurs** : Accédez à des données spécifiques avec `loc` et `iloc`.
# - **Étude statistique rapide** : Analysez vos données avec `describe` et `value_counts`.
#
# **Rappel** : En Python, appliquez une méthode à un objet en l'ajoutant après celui-ci, suivi de parenthèses. Exemple : `mon_objet.ma_méthode()`.
#
# > Visualisation d'un DataFrame: méthode head, attributs columns et shape
#
# Il est possible d'avoir un aperçu d'un jeu de données en affichant **les premières lignes** du DataFrame.
#
# - Utilisez la méthode `head()` en spécifiant en argument le **nombre de lignes** à afficher (par défaut : 5).
# - Pour afficher les **dernières lignes**, utilisez la méthode `tail()` de la même manière.
#
# Exemple :
#
# ```python
# # Affichage des 10 premières lignes d'un DataFrame mon_dataframe
# mon_dataframe.head(10)

# %%
# Afficher les 20 premières lignes du DataFrame transactions.
transactions.head(20)
# Out:
#                 cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# transaction_id
# 80712190438      270351  28-02-2014                 1              1   -5
# 29258453508      270384  27-02-2014                 5              3   -5
# 51750724947      273420  24-02-2014                 6              5   -2
# 93274880719      271509  24-02-2014                11              6   -3
# 51750724947      273420  23-02-2014                 6              5   -2
# 97439039119      272357  23-02-2014                 8              3   -2
# 45649838090      273667  22-02-2014                11              6   -1
# 22643667930      271489  22-02-2014                12              6   -1
# 79792372943      275108  22-02-2014                 3              1   -3
# 50076728598      269014  21-02-2014                 8              3   -4
# 29258453508      270384  20-02-2014                 5              3    5
# ...

# %%
# Affichage des 10 dernieres lignes du DF
transactions.tail(10)
# Out:
#                 cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# transaction_id
# 49882891062      271982  25-01-2011                10              5    4
# 14787475597      273982  25-01-2011                 4              3    5
# 50691119572      273031  25-01-2011                 6              5    1
# 40893803228      272049  25-01-2011                11              6    3
# 30856003613      266866  25-01-2011                 4              2    2
# 94340757522      274550  25-01-2011                12              5    1
# 89780862956      270022  25-01-2011                 4              1    1
# 85115299378      271020  25-01-2011                 2              6    4
# 72870271171      270911  25-01-2011                11              5    3
# 77960931771      271961  25-01-2011                11              5    1
#
#                 Rate      Tax  total_amt Store_type
# transaction_id
# 49882891062     1330  558.600   5878.600     e-Shop
# ...

# %% [markdown]
# > Afficher les dimensions du DataFrame transactions ainsi que le nom de la 5ème colonne. Rappelez-vous qu'en Python les indices commencent à 0.

# %%
# Affiche les dimensions du DF transactions
transactions.shape # autrement dit 23059 lignes pour 9 colonnes

# Affiche le nom de la 5e colonne
transactions.columns[4]
# Out:
# 'Qty'

# %% [markdown]
# + (a) Dans un DataFrame nommé `cat`, stocker les variables catégorielles de transactions.
# + (b) Dans un DataFrame nommé `num`, stocker les variables quantitatives de transactions.
# + (c) Afficher les 5 premières lignes de chaque DataFrame.

# %%
# Stocke les variables catégorielles de transactions
transactions.columns
cat = transactions[['cust_id', 'tran_date', 'prod_subcat_code', 'prod_cat_code', 'Store_type']]
num = transactions[['Qty', 'Rate', 'Tax', 'total_amt']]

# Afficher les 5 premières lignes de chaque DataFrame.
cat.head(5)
# Out:
#                 cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# transaction_id
# 80712190438      270351  28-02-2014                 1              1
# 29258453508      270384  27-02-2014                 5              3
# 51750724947      273420  24-02-2014                 6              5
# 93274880719      271509  24-02-2014                11              6
# 51750724947      273420  23-02-2014                 6              5
#
#                Store_type
# transaction_id
# 80712190438        e-Shop
# 29258453508        e-Shop
# 51750724947      TeleShop
# 93274880719        e-Shop
# 51750724947      TeleShop

# %%
num.head(5)
# Out:
#                 Qty  Rate      Tax  total_amt
# transaction_id
# 80712190438      -5  -772  405.300  -4265.300
# 29258453508      -5 -1497  785.925  -8270.925
# 51750724947      -2  -791  166.110  -1748.110
# 93274880719      -3 -1363  429.345  -4518.345
# 51750724947      -2  -791  166.110  -1748.110

# %% [markdown]
# Le gérant des transactions répertoriées dans le DataFrame transactions souhaite avoir accès aux identifiants des clients ayant fait un achat en ligne (c'est-à-dire dans un "e-Shop") ainsi que la date de la transaction correspondante.
#
# Nous avons les informations suivantes concernant les colonnes de transactions :
#
#
# |  Nom de la colonne  |                      Description                    |
# |---------------------|-----------------------------------------------------|
# |           'cust_id' |    Les identifiants des clients                     |
# |       'Store_type'  |    Le type de magasin où s'est faite la transaction |
# |       'tran_date'   |    La date des transactions                         |
# >
#
# + (a) Dans un DataFrame nommé transactions_eshop, stocker les transactions qui ont lieu dans un magasin de type "e-Shop".
#
# + (b) Dans un autre DataFrame nommé transactions_id_date, stocker les identifiants des clients et la date des transactions du DataFrame transactions_eshop.
#
# + (c) Afficher les 5 premières lignes de transactions_id_date.

# %%
# Stocke les transactions qui ont lieu dans le magasin e-shop

transactions_eshop = transactions[transactions["Store_type"] == "e-Shop"]
transactions_eshop
# Out:
#                 cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# transaction_id
# 80712190438      270351  28-02-2014                 1              1   -5
# 29258453508      270384  27-02-2014                 5              3   -5
# 93274880719      271509  24-02-2014                11              6   -3
# 45649838090      273667  22-02-2014                11              6   -1
# 50076728598      269014  21-02-2014                 8              3   -4
# ...                 ...         ...               ...            ...  ...
# 49882891062      271982  25-01-2011                10              5    4
# 14787475597      273982  25-01-2011                 4              3    5
# 40893803228      272049  25-01-2011                11              6    3
# 94340757522      274550  25-01-2011                12              5    1
# 89780862956      270022  25-01-2011                 4              1    1
#
#                 Rate      Tax  total_amt Store_type
# ...

# %%
# Stocke les date de transaction du magasin e-shop et Affiche les 5 premieres lignes

transactions_id_date = transactions_eshop[['cust_id', 'tran_date']]
transactions_id_date.head(5)
# Out:
#                 cust_id   tran_date
# transaction_id
# 80712190438      270351  28-02-2014
# 29258453508      270384  27-02-2014
# 93274880719      271509  24-02-2014
# 45649838090      273667  22-02-2014
# 50076728598      269014  21-02-2014

# %% [markdown]
# À présent, le gérant voudrait avoir accès aux transactions effectuées par le client d'identifiant 268819.
#
# + (d) Dans un DataFrame nommé transactions_client_268819, stocker toutes les transactions dont l'identifiant du client est 268819.
# + (e) Une colonne d'un DataFrame peut être parcourue comme une liste dans une boucle for. À l'aide d'une boucle for sur la colonne 'total_amt', calculer et afficher le montant total des transactions du client 268819.

# %%
# Stockons les transactions du client 268819

transactions_client_268819 = transactions[transactions['cust_id'] == 268819]
transactions_client_268819
# Out:
#                 cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# transaction_id
# 11878870074      268819  26-01-2014                10              5   -4
# 11878870074      268819  23-01-2014                10              5    4
# 22303224302      268819  19-12-2013                10              5   -2
# 22303224302      268819  11/12/2013                10              5    2
# 9987404340       268819   7/10/2013                10              5    1
# 95368989068      268819    9/7/2013                11              5    2
# 41666150977      268819   11/6/2013                12              6    3
# 81299333982      268819  13-05-2013                 5              3    2
# 81541766449      268819  30-09-2012                 9              3    5
# 8703595902       268819    6/4/2012                 3              1    3
# 93712197376      268819  17-07-2011                 2              6    4
# ...

# %%
# Avec la boucle "For" Calculons et affichons les montants des transactions du client 228819 sur la colonne "total_amt"
# Initialiser une variable pour le total des transactions du client 268819
montant_total = 0
for montant in transactions['total_amt']:
    montant_total += montant

# Afficher le résultat
print(f"Montant total des transactions du client 268819 : {montant_total}")
# Out:
# Montant total des transactions du client 268819 : 48579771.36999987

# %%
montant_total = transactions_client_268819['total_amt'].sum()
print(f"Montant total des transactions du client 268819 : {montant_total}")
# Out:
# Montant total des transactions du client 268819 : 14911.974999999999

# %% [markdown]
# # Étude statistique rapide des données d'un DataFrame
#
# + (a) Utiliser la méthode describe du DataFrame transactions.
#
# + (b) Les variables quantitatives sont 'Qty', 'Rate', 'Tax' et total_amt. Est-ce que par défaut les statistiques produites par la méthode describe ne sont calculées que sur les variables quantitatives ?
#
# + (c) Afficher le nombre d'occurences de chaque modalité que prend la variable Store_type à l'aide de la méthode value_counts.

# %%
# Utilisation de la methode describe
transactions.describe()
# Out:
#              cust_id  prod_subcat_code  prod_cat_code           Qty  \
# count   23053.000000      23053.000000   23053.000000  23053.000000
# mean   271021.746497          6.149091       3.763632      2.432395
# std      2431.692059          3.726372       1.677016      2.268406
# min    266783.000000          1.000000       1.000000     -5.000000
# 25%    268935.000000          3.000000       2.000000      1.000000
# 50%    270980.000000          5.000000       4.000000      3.000000
# 75%    273114.000000         10.000000       5.000000      4.000000
# max    275265.000000         12.000000       6.000000      5.000000
#
#                Rate           Tax     total_amt
# count  23053.000000  23053.000000  23053.000000
# mean     636.369713    248.667192   2107.308002
# std      622.363498    187.177773   2507.561264
# min    -1499.000000      7.350000  -8270.925000
# 25%      312.000000     98.280000    762.450000
# 50%      710.000000    199.080000   1754.740000
# ...

# %%
num.describe()
# Out:
#                 Qty          Rate           Tax     total_amt
# count  23053.000000  23053.000000  23053.000000  23053.000000
# mean       2.432395    636.369713    248.667192   2107.308002
# std        2.268406    622.363498    187.177773   2507.561264
# min       -5.000000  -1499.000000      7.350000  -8270.925000
# 25%        1.000000    312.000000     98.280000    762.450000
# 50%        3.000000    710.000000    199.080000   1754.740000
# 75%        4.000000   1109.000000    365.715000   3569.150000
# max        5.000000   1500.000000    787.500000   8287.500000

# %%
cat.describe()
# Out:
#              cust_id  prod_subcat_code  prod_cat_code
# count   23053.000000      23053.000000   23053.000000
# mean   271021.746497          6.149091       3.763632
# std      2431.692059          3.726372       1.677016
# min    266783.000000          1.000000       1.000000
# 25%    268935.000000          3.000000       2.000000
# 50%    270980.000000          5.000000       4.000000
# 75%    273114.000000         10.000000       5.000000
# max    275265.000000         12.000000       6.000000

# %%
transactions['Store_type'].value_counts()
# Out:
# Store_type
# e-Shop            9311
# MBR               4661
# Flagship store    4577
# TeleShop          4504
# Name: count, dtype: int64

# %% [markdown]
# La méthode describe a calculé des statistiques sur les variables cust_id, prod_subcat_code et prod_cat_code alors que celles-ci sont des variables catégorielles.
#
# > Bien sûr, ces statistiques n'ont aucun sens. La méthode describe a traité ces variables comme quantitatives car les modalités qu'elles prennent sont de type numérique. C'est pourquoi il faut faire attention aux résultats retournés par la méthode describe et toujours prendre du recul sur ce que représentent les variables contenues dans le DataFrame.
#
#
# Le gérant des transactions souhaite faire un rapport rapide sur les caractéristiques des transactions : il souhaite notamment connaître le montant moyen dépensé ainsi que la quantité maximale achetée.
#
# + (d) Quel est le montant total moyen dépensé ? On s'intéressera à la colonne 'total_amt' de transactions.
# + (e) Quelle est la quantité maximale achetée ? On s'intéressera à la colonne 'Qty' de transactions.

# %%
montant_total_moyen = transactions['total_amt'].mean()
montant_total_moyen
# Out:
# np.float64(2107.308001995402)

# %%
quantite_max_achete = transactions["Qty"].max()
quantite_max_achete
# Out:
# np.int64(5)

# %% [markdown]
# > Certaines transactions ont des montants négatifs.
# Il s'agit de transactions qui ont été annulées et remboursées au client.
# Ces montants vont perturber la distribution des montants ce qui nous donne de mauvaises estimations des moyennes et quantiles de la variable total_amt.
#
# + (f) Quelle est la moyenne du montant des transactions dont le montant est positif ?

# %%
moyenne_positive = transactions[transactions['total_amt']>0].describe()
moyenne_positive
# Out:
#              cust_id  prod_subcat_code  prod_cat_code           Qty  \
# count   20876.000000      20876.000000   20876.000000  20876.000000
# mean   271027.141981          6.156639       3.761496      3.003497
# std      2433.338935          3.722363       1.675859      1.420479
# min    266783.000000          1.000000       1.000000      1.000000
# 25%    268938.000000          3.000000       2.000000      2.000000
# 50%    271004.000000          5.000000       4.000000      3.000000
# 75%    273122.250000         10.000000       5.000000      4.000000
# max    275265.000000         12.000000       6.000000      5.000000
#
#                Rate           Tax     total_amt
# count  20876.000000  20876.000000  20876.000000
# mean     785.927764    247.861232   2608.444389
# std      415.586498    186.644248   1964.208517
# min       70.000000      7.350000     77.350000
# 25%      426.000000     97.938750   1030.688750
# 50%      788.000000    198.555000   2089.555000
# ...
